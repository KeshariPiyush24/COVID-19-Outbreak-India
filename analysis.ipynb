# %% [markdown]
# # COVID-19 Outbreak India Analysis (LIVE)

# %% [markdown]
# ## Pie Chart To Show Total Cases in India

# %%
# %run scripts/piechart.py
# Out:
# Matplotlib is building the font cache; this may take a moment.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# D:\a\COVID-19-Outbreak-India\COVID-19-Outbreak-India\scripts\piechart.py in <module>
#       9     pie = pattern.match(f.readline())
#      10     plt.style.use('seaborn-dark')
# ---> 11     plt.pie([pie.group(i) for i in range(2, 5)], autopct='%2.2f%%', labels=['Recovered', 'Deaths', 'Active'], startangle=90, wedgeprops={
#      12         'edgecolor': 'white'})
#      13     plt.rcParams['figure.dpi'] = 100
#
# D:\a\COVID-19-Outbreak-India\COVID-19-Outbreak-India\scripts\piechart.py in <listcomp>(.0)
#       9     pie = pattern.match(f.readline())
#      10     plt.style.use('seaborn-dark')
# ---> 11     plt.pie([pie.group(i) for i in range(2, 5)], autopct='%2.2f%%', labels=['Recovered', 'Deaths', 'Active'], startangle=90, wedgeprops={
#      12         'edgecolor': 'white'})
#      13     plt.rcParams['figure.dpi'] = 100
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %% [markdown]
# # Tabel To display information of all states and union territories in India

# %%
# %run scripts/table.py
# Out:
# Empty DataFrame
# Columns: [<!DOCTYPE html>GitHub Pages is temporarily down for maintenance.</html>]
# Index: []

# %% [markdown]
# # Top 10 Affected States Bar Graph

# %%
# %run scripts/bars.py
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\a\COVID-19-Outbreak-India\COVID-19-Outbreak-India\scripts\bars.py in <module>
#      50
#      51
# ---> 52 analyze()
#
# D:\a\COVID-19-Outbreak-India\COVID-19-Outbreak-India\scripts\bars.py in analyze()
#      36     plt.style.use('fivethirtyeight')
#      37     plt.title('Top 10 States With Active COVID-19 Cases')
# ---> 38     plt.barh([x-1.5 for x in ran], [d['Confirmed']
#      39                                     for d in top10states.values()], 1.5, color='darkorange')
#      40     plt.barh(ran, [d['Recovered']
#
# c:\hostedtoolcache\windows\python\3.8.5\x64\lib\site-packages\matplotlib\pyplot.py in barh(y, width, height, left, align, **kwargs)
#    2484 @_copy_docstring_and_deprecators(Axes.barh)
#    2485 def barh(y, width, height=0.8, left=None, *, align='center', **kwargs):
# -> 2486     return gca().barh(
#    2487         y, width, height=height, left=left, align=align, **kwargs)
#    2488
#
# c:\hostedtoolcache\windows\python\3.8.5\x64\lib\site-packages\matplotlib\axes\_axes.py in barh(self, y, width, height, left, align, **kwargs)
#    2628         """
#    2629         kwargs.setdefault('orientation', 'horizontal')
# -> 2630         patches = self.bar(x=left, height=height, width=width, bottom=y,
#    2631                            align=align, **kwargs)
#    2632         return patches
#
# c:\hostedtoolcache\windows\python\3.8.5\x64\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\hostedtoolcache\windows\python\3.8.5\x64\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2428                 yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
#    2429
# -> 2430         x, height, width, y, linewidth = np.broadcast_arrays(
#    2431             # Make args iterable too.
#    2432             np.atleast_1d(x), height, width, y, linewidth)
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# c:\hostedtoolcache\windows\python\3.8.5\x64\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(subok, *args)
#     256     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     257
# --> 258     shape = _broadcast_shape(*args)
#     259
#     260     if all(array.shape == shape for array in args):
#
# c:\hostedtoolcache\windows\python\3.8.5\x64\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     187     # use the old-iterator because np.nditer does not handle size 0 arrays
#     188     # consistently
# --> 189     b = np.broadcast(*args[:32])
#     190     # unfortunately, it cannot handle 32 or more arguments directly
#     191     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %% [markdown]
# # API source
# [api.covid19india.org](https://api.covid19india.org)

# %% [markdown]
# # Contributor:
# [Piyush Keshari](https://github.com/insane-banda)
