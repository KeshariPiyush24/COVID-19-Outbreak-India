# %% [markdown]
# # COVID-19 Outbreak India Analysis (LIVE)

# %% [markdown]
# ## Pie Chart To Show Total Cases in India

# %%
# %run scripts/piechart.py

# %% [markdown]
# # Tabel To display information of all states and union territories in India

# %%
# %run scripts/table.py
# Out:
#                                        State  Confirmed  Recovered  Deaths  \
# 1                                Maharashtra    27524.0       6059    1019
# 2                                 Tamil Nadu     9674.0       2240      66
# 3                                    Gujarat     9592.0       3753     586
# 4                                      Delhi     8470.0       3045     115
# 5                             Madhya Pradesh     4426.0       2171     237
# 6                                  Rajasthan     4534.0       2638     125
# 7                              Uttar Pradesh     3902.0       2072      88
# 8                                West Bengal     2377.0        768     215
# 9                             Andhra Pradesh     2205.0       1192      48
# 10                                    Punjab     1935.0        223      32
# 11                                 Telangana     1414.0        952      34
# 12                                     Bihar      999.0        400       7
# 13                                 Karnataka      987.0        460      35
# 14                         Jammu and Kashmir      983.0        485      11
# 15                                   Haryana      818.0        439      11
# 16                                    Odisha      624.0        158       3
# 17                                    Kerala      561.0        493       4
# 18                                Chandigarh      191.0         37       3
# 19                                 Jharkhand        NaN         87       3
# 20                                   Tripura      156.0         29       0
# 21                                     Assam       87.0         40       2
# 22                               Uttarakhand       78.0         50       1
# 23                          Himachal Pradesh       74.0         35       3
# 24                              Chhattisgarh       60.0         56       0
# 25                                    Ladakh       43.0         22       0
# 26               Andaman and Nicobar Islands       33.0         33       0
# 27                                       Goa       15.0          7       0
# 28                                 Meghalaya       13.0         11       1
# 29                                Puducherry       13.0          9       0
# 30                                   Manipur        3.0          2       0
# 31                                   Mizoram        1.0          1       0
# 32                         Arunachal Pradesh        1.0          1       0
# 33  Dadra and Nagar Haveli and Daman and Diu        1.0          1       0
# 34                                  Nagaland        0.0          0       0
# 35                             Daman and Diu        0.0          0       0
# 36                               Lakshadweep        0.0          0       0
# 37                                    Sikkim        0.0          0       0
#
#     Active
# 1    20446
# 2     7368
# 3     5253
# 4     5310
# 5     2018
# 6     1771
# 7     1742
# 8     1394
# 9      965
# 10    1680
# 11     428
# 12     592
# 13     491
# 14     487
# 15     368
# 16     463
# 17      64
# 18     151
# 19     -90
# 20     127
# 21      44
# 22      27
# 23      33
# 24       4
# 25      21
# 26       0
# 27       8
# 28       1
# 29       4
# 30       1
# 31       0
# 32       0
# 33       0
# 34       0
# 35       0
# 36       0
# 37       0

# %% [markdown]
# # Top 10 Affected States Bar Graph

# %%
# %run scripts/bars.py
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\a\COVID-19-Outbreak-India\COVID-19-Outbreak-India\scripts\bars.py in <module>
#      50
#      51
# ---> 52 analyze()
#
# D:\a\COVID-19-Outbreak-India\COVID-19-Outbreak-India\scripts\bars.py in analyze()
#      31
#      32 def analyze():
# ---> 33     storedata()
#      34     top10()
#      35     ran = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45]
#
# D:\a\COVID-19-Outbreak-India\COVID-19-Outbreak-India\scripts\bars.py in storedata()
#      14         for line in csv_reader:
#      15             if(line['State'] != 'Total'):
# ---> 16                 states[line['State']] = {'Confirmed': int(line['Confirmed']),
#      17                                          'Recovered': int(line['Recovered']),
#      18                                          'Deaths': int(line['Deaths'])}
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# # API source
# [api.covid19india.org](https://api.covid19india.org)

# %% [markdown]
# # Contributor:
# [Piyush Keshari](https://github.com/PiyushKe)
