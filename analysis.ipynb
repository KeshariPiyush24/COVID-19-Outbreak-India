# %% [markdown]
# # COVID-19 Outbreak India Analysis (LIVE)

# %% [markdown]
# ## Pie Chart To Show Total Cases in India

# %%
# %run scripts/piechart.py

# %% [markdown]
# # Tabel To display information of all states and union territories in India

# %%
# %run scripts/table.py
# Out:
#                                        State  Confirmed  Recovered  Deaths  \
# 1                                Maharashtra     180298      93154    8053
# 2                                 Tamil Nadu      98392      56021    1321
# 3                                      Delhi      92175      63007    2864
# 4                                    Gujarat      33999      24601    1888
# 5                              Uttar Pradesh      24825      17221     735
# 6                                  Rajasthan      18427      14643     426
# 7                                West Bengal      19819      13037     699
# 8                             Madhya Pradesh      14106      10815     589
# 9                                    Haryana      15509      11019     251
# 10                          State Unassigned       6832          0       0
# 11                                 Karnataka      18016       8336     272
# 12                            Andhra Pradesh      16097       7313     198
# 13                                     Bihar      10392       7994      78
# 14                                 Telangana      17357       8082     267
# 15                         Jammu and Kashmir       7849       4974     115
# 16                                     Assam       8956       6107      14
# 17                                    Odisha       7545       5502      35
# 18                                    Punjab       5784       4144     152
# 19                                    Kerala       4754       2638      26
# 20                               Uttarakhand       2984       2405      42
# 21                              Chhattisgarh       2940       2303      14
# 22                                 Jharkhand       2525       1931      15
# 23                                   Tripura       1401       1093       1
# 24                                    Ladakh        991        729       1
# 25                                       Goa       1482        734       4
# 26                          Himachal Pradesh       1011        629       9
# 27                                   Manipur       1279        616       0
# 28                                Chandigarh        450        389       6
# 29                                Puducherry        802        331      12
# 30                                  Nagaland        535        197       0
# 31                                   Mizoram        160        126       0
# 32                         Arunachal Pradesh        195         66       1
# 33                                    Sikkim         89         52       0
# 34  Dadra and Nagar Haveli and Daman and Diu        254        112       0
# 35               Andaman and Nicobar Islands        109         51       0
# 36                                 Meghalaya         55         42       1
# 37                               Lakshadweep          0          0       0
#
#     Active
# 1    79075
# 2    41050
# 3    26304
# 4     7510
# 5     6869
# 6     3358
# 7     6083
# 8     2702
# 9     4239
# 10    6832
# 11    9404
# 12    8586
# 13    2320
# 14    9008
# 15    2760
# 16    2832
# 17    2008
# 18    1488
# 19    2088
# 20     510
# 21     623
# 22     579
# 23     307
# 24     261
# 25     744
# 26     360
# 27     663
# 28      55
# 29     459
# 30     338
# 31      34
# 32     128
# 33      37
# 34     141
# 35      58
# 36      12
# 37       0

# %% [markdown]
# # Top 10 Affected States Bar Graph

# %%
# %run scripts/bars.py

# %% [markdown]
# # API source
# [api.covid19india.org](https://api.covid19india.org)

# %% [markdown]
# # Contributor:
# [Piyush Keshari](https://github.com/PiyushKe)
